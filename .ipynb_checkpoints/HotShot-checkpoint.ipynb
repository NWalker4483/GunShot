# %%
import librosa
import matplotlib.pyplot as plt
from matplotlib import figure=
sound_names = ["air conditioner","car horn","children playing","dog bark","drilling","engine idling",
               "gun shot","jackhammer","siren","street music"]

# %% [markdown]
# ## Designing the Model

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Model, load_model, Sequential
from keras.layers import Dense, Activation, Dropout, Input, TimeDistributed, LSTM, Conv1D
from keras.layers import GRU, Bidirectional, BatchNormalization, Reshape
from keras.optimizers import Adam

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
#TODO: Convert to format below 
"""
model = Sequential()
model.add(Dense(32, input_dim=784))
model.add(Activation('relu'))
""" 
def model(input_shape):
    X = Sequential
    """
    Function creating the model's graph in Keras.
    
    Argument:
    input_shape -- shape of the model's input data (using Keras conventions)

    Returns:
    model -- Keras model instance
    """
    X_input = Input(shape = input_shape)
    
    # Step 1: CONV layer
    X = Conv1D(196, kernel_size=15, strides=4)(X_input)   # CONV1D
    X = BatchNormalization()(X)                           # Batch normalization
    X = Activation('relu')(X)                             # ReLu activation
    X = Dropout(0.8)(X)                                   # dropout (use 0.8)

    # Step 2: First GRU Layer
    X = GRU(units = 128, return_sequences = True)(X)      # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                   # dropout (use 0.8)
    X = BatchNormalization()(X)                           # Batch normalization
    
    # Step 3: Second GRU Layer
    X = GRU(units = 128, return_sequences = True)(X)      # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                   # dropout (use 0.8)
    X = BatchNormalization()(X)                           # Batch normalization
    X = Dropout(0.8)(X)                                   # dropout (use 0.8)
    
    # Step 4: Time-distributed dense layer
    X = TimeDistributed(Dense(1, activation = "sigmoid"))(X) # time distributed  (sigmoid)
    model = Model(inputs = X_input, outputs = X)    
    return model  

SPQ = 5511 # The number of samples feed into the spectogram -> model 
n_freq = 101 # Number of frequencies input to the model at each time step of the spectrogram

model = model(input_shape = (SPQ, n_freq))
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy"])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c2d0607d82e3> in <module>
#      39 n_freq = 101 # Number of frequencies input to the model at each time step of the spectrogram
#      40
# ---> 41 model = model(input_shape = (SPQ, n_freq))
#      42 opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
#      43 model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy"])
#
# <ipython-input-26-c2d0607d82e3> in model(input_shape)
#      14
#      15     # Step 1: CONV layer
# ---> 16     X.add(Conv1D(196, kernel_size=15, strides=4,
#      17                input_shape = input_shape))  # CONV1D
#      18     X.add(BatchNormalization())                          # Batch normalization
#
# AttributeError: 'Model' object has no attribute 'add'

# %% [markdown]
# ## Prepping the Data

# %%
import os
import wave
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
def get_spectrogram(data, plot = False):
    """
    Function to compute a spectrogram.
    
    Argument:
    predictions -- one channel / dual channel audio data as numpy array

    Returns:
    pxx -- spectrogram, 2-D array, columns are the periodograms of successive segments.
    """
    nfft = 200 # Length of each window segment
    fs = 8000 # Sampling frequencies
    noverlap = 120 # Overlap between windows
    nchannels = data.ndim
    if nchannels != 1:
        data = data[:,0]
    if not plot:
        pxx, _, _ = mlab.specgram(data, nfft, fs, noverlap = noverlap)
    else:
        pxx, _, _, _ = plt.specgram(data, nfft, fs, noverlap = noverlap)
    return pxx

def get_wav_info(wav_file):
    wav = wave.open(wav_file, 'r')
    frames = wav.readframes(-1)
    sound_info = pylab.fromstring(frames, 'int16')
    frame_rate = wav.getframerate()
    wav.close()
    return sound_info
pxx = get_spectrogram(get_wav_info("UrbanSound/car_horn/2937.wav"),plot = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
import glob
import os 
import numpy as np
def parse_files(parent_dir,sub_dirs,file_ext="*.wav",callback = None):
    assert(callback != None)
    All = []
    for label, sub_dir in enumerate(sub_dirs):
        for fn in glob.glob(os.path.join(parent_dir, sub_dir, file_ext)):
            try:
              All.append([callback(fn),label])
            except Exception as e:
              print("Error encountered while parsing file: ", fn)
              continue
    return np.array(All)

# %%
sound_names = ["air conditioner","car horn","children playing","dog bark","drilling","engine idling",
               "gun shot","jackhammer","siren","street music"]
parent_dir = 'UrbanSound'
sub_dirs = ["_".join(i.split()) for i in sound_names]
a = parse_files(parent_dir,sub_dirs,callback = graph_spectrogram)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# Error encountered while parsing file:  UrbanSound\air_conditioner\101729.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\121285.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\121286.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\127872.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\127873.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\134717.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\146690.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\146709.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\146714.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\146845.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\147926.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\151977.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\153261.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\162103.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\165454.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\166942.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\167464.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\170245.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\178686.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\185709.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\189023.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\195969.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\202516.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\202517.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\204240.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\30204.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\35382.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\47160.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\50901.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\56385.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\57320.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\60846.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\62461.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\63724.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\73524.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\74507.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\79089.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\80589.wav
# Error encountered while parsing file:  UrbanSound\air_conditioner\83502.wav
# Error encountered while parsing file:  UrbanSound\car_horn\107090.wav
# Error encountered while parsing file:  UrbanSound\car_horn\117536.wav
# Error encountered while parsing file:  UrbanSound\car_horn\118070.wav
# Error encountered while parsing file:  UrbanSound\car_horn\118496.wav
# Error encountered while parsing file:  UrbanSound\car_horn\125520.wav
# Error encountered while parsing file:  UrbanSound\car_horn\138465.wav
# Error encountered while parsing file:  UrbanSound\car_horn\138468.wav
# Error encountered while parsing file:  UrbanSound\car_horn\143115.wav
# Error encountered while parsing file:  UrbanSound\car_horn\14524.wav
# Error encountered while parsing file:  UrbanSound\car_horn\145577.wav
# Error encountered while parsing file:  UrbanSound\car_horn\151359.wav
# Error encountered while parsing file:  UrbanSound\car_horn\153057.wav
# Error encountered while parsing file:  UrbanSound\car_horn\155129.wav
# Error encountered while parsing file:  UrbanSound\car_horn\155130.wav
# Error encountered while parsing file:  UrbanSound\car_horn\155234.wav
# Error encountered while parsing file:  UrbanSound\car_horn\155283.wav
# Error encountered while parsing file:  UrbanSound\car_horn\156091.wav
# Error encountered while parsing file:  UrbanSound\car_horn\156194.wav
# Error encountered while parsing file:  UrbanSound\car_horn\161010.wav
# Error encountered while parsing file:  UrbanSound\car_horn\162540.wav
# Error encountered while parsing file:  UrbanSound\car_horn\162541.wav
# Error encountered while parsing file:  UrbanSound\car_horn\162702.wav
# Error encountered while parsing file:  UrbanSound\car_horn\162703.wav
# Error encountered while parsing file:  UrbanSound\car_horn\162728.wav
# Error encountered while parsing file:  UrbanSound\car_horn\164625.wav
# Error encountered while parsing file:  UrbanSound\car_horn\164626.wav
# Error encountered while parsing file:  UrbanSound\car_horn\164627.wav
# Error encountered while parsing file:  UrbanSound\car_horn\170243.wav
# Error encountered while parsing file:  UrbanSound\car_horn\17074.wav
# Error encountered while parsing file:  UrbanSound\car_horn\17124.wav
# Error encountered while parsing file:  UrbanSound\car_horn\17307.wav
# Error encountered while parsing file:  UrbanSound\car_horn\174840.wav
# Error encountered while parsing file:  UrbanSound\car_horn\174841.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175842.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175843.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175844.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175845.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175846.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175847.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175848.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175849.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175850.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175851.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175852.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175853.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175854.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175855.wav
# Error encountered while parsing file:  UrbanSound\car_horn\175856.wav
# Error encountered while parsing file:  UrbanSound\car_horn\176003.wav
# Error encountered while parsing file:  UrbanSound\car_horn\176631.wav
# Error encountered while parsing file:  UrbanSound\car_horn\176634.wav
# Error encountered while parsing file:  UrbanSound\car_horn\176638.wav
# Error encountered while parsing file:  UrbanSound\car_horn\178115.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179858.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179860.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179861.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179862.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179863.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179864.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179865.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179866.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179867.wav
# Error encountered while parsing file:  UrbanSound\car_horn\179868.wav
# Error encountered while parsing file:  UrbanSound\car_horn\180156.wav
# Error encountered while parsing file:  UrbanSound\car_horn\182474.wav
# Error encountered while parsing file:  UrbanSound\car_horn\184355.wav
# Error encountered while parsing file:  UrbanSound\car_horn\187356.wav
# Error encountered while parsing file:  UrbanSound\car_horn\18933.wav
# Error encountered while parsing file:  UrbanSound\car_horn\19026.wav
# Error encountered while parsing file:  UrbanSound\car_horn\204765.wav
# Error encountered while parsing file:  UrbanSound\car_horn\24074.wav
# Error encountered while parsing file:  UrbanSound\car_horn\24076.wav
# Error encountered while parsing file:  UrbanSound\car_horn\26176.wav
# Error encountered while parsing file:  UrbanSound\car_horn\26177.wav
# Error encountered while parsing file:  UrbanSound\car_horn\26185.wav
# Error encountered while parsing file:  UrbanSound\car_horn\26186.wav
# Error encountered while parsing file:  UrbanSound\car_horn\27068.wav
# Error encountered while parsing file:  UrbanSound\car_horn\28808.wav
# Error encountered while parsing file:  UrbanSound\car_horn\2937.wav
# Error encountered while parsing file:  UrbanSound\car_horn\29932.wav
# Error encountered while parsing file:  UrbanSound\car_horn\32417.wav
# Error encountered while parsing file:  UrbanSound\car_horn\42101.wav
# Error encountered while parsing file:  UrbanSound\car_horn\43802.wav
# Error encountered while parsing file:  UrbanSound\car_horn\43803.wav
# Error encountered while parsing file:  UrbanSound\car_horn\44278.wav
# Error encountered while parsing file:  UrbanSound\car_horn\46391.wav
# Error encountered while parsing file:  UrbanSound\car_horn\49974.wav
# Error encountered while parsing file:  UrbanSound\car_horn\52102.wav
# Error encountered while parsing file:  UrbanSound\car_horn\54086.wav
# Error encountered while parsing file:  UrbanSound\car_horn\54187.wav
# Error encountered while parsing file:  UrbanSound\car_horn\57607.wav
# Error encountered while parsing file:  UrbanSound\car_horn\58202.wav
# Error encountered while parsing file:  UrbanSound\car_horn\65472.wav
# Error encountered while parsing file:  UrbanSound\car_horn\66115.wav
# Error encountered while parsing file:  UrbanSound\car_horn\68657.wav
# Error encountered while parsing file:  UrbanSound\car_horn\73168.wav
# Error encountered while parsing file:  UrbanSound\car_horn\82317.wav
# Error encountered while parsing file:  UrbanSound\car_horn\83465.wav
# Error encountered while parsing file:  UrbanSound\car_horn\83488.wav
# Error encountered while parsing file:  UrbanSound\car_horn\87275.wav
# Error encountered while parsing file:  UrbanSound\car_horn\89679.wav
# Error encountered while parsing file:  UrbanSound\car_horn\94401.wav
# Error encountered while parsing file:  UrbanSound\car_horn\94868.wav
# Error encountered while parsing file:  UrbanSound\car_horn\99812.wav
# Error encountered while parsing file:  UrbanSound\children_playing\100263.wav
# Error encountered while parsing file:  UrbanSound\children_playing\104327.wav
# Error encountered while parsing file:  UrbanSound\children_playing\108362.wav
# Error encountered while parsing file:  UrbanSound\children_playing\116423.wav
# Error encountered while parsing file:  UrbanSound\children_playing\123399.wav
# Error encountered while parsing file:  UrbanSound\children_playing\129356.wav
# Error encountered while parsing file:  UrbanSound\children_playing\129750.wav
# Error encountered while parsing file:  UrbanSound\children_playing\132855.wav
# Error encountered while parsing file:  UrbanSound\children_playing\133090.wav
# Error encountered while parsing file:  UrbanSound\children_playing\133494.wav
# Error encountered while parsing file:  UrbanSound\children_playing\135776.wav
# Error encountered while parsing file:  UrbanSound\children_playing\138031.wav
# Error encountered while parsing file:  UrbanSound\children_playing\142003.wav
# Error encountered while parsing file:  UrbanSound\children_playing\151149.wav
# Error encountered while parsing file:  UrbanSound\children_playing\155219.wav
# Error encountered while parsing file:  UrbanSound\children_playing\155238.wav
# Error encountered while parsing file:  UrbanSound\children_playing\155262.wav
# Error encountered while parsing file:  UrbanSound\children_playing\155263.wav
# Error encountered while parsing file:  UrbanSound\children_playing\155280.wav
# Error encountered while parsing file:  UrbanSound\children_playing\156200.wav
# Error encountered while parsing file:  UrbanSound\children_playing\158593.wav
# Error encountered while parsing file:  UrbanSound\children_playing\158597.wav
# Error encountered while parsing file:  UrbanSound\children_playing\159439.wav
# Error encountered while parsing file:  UrbanSound\children_playing\159735.wav
# Error encountered while parsing file:  UrbanSound\children_playing\160009.wav
# Error encountered while parsing file:  UrbanSound\children_playing\160010.wav
# Error encountered while parsing file:  UrbanSound\children_playing\160011.wav
# Error encountered while parsing file:  UrbanSound\children_playing\160016.wav
# Error encountered while parsing file:  UrbanSound\children_playing\164194.wav
# Error encountered while parsing file:  UrbanSound\children_playing\164797.wav
# Error encountered while parsing file:  UrbanSound\children_playing\165067.wav
# Error encountered while parsing file:  UrbanSound\children_playing\165529.wav
# Error encountered while parsing file:  UrbanSound\children_playing\169043.wav
# Error encountered while parsing file:  UrbanSound\children_playing\169044.wav
# Error encountered while parsing file:  UrbanSound\children_playing\169045.wav
# Error encountered while parsing file:  UrbanSound\children_playing\17009.wav
# Error encountered while parsing file:  UrbanSound\children_playing\170564.wav
# Error encountered while parsing file:  UrbanSound\children_playing\172593.wav
# Error encountered while parsing file:  UrbanSound\children_playing\174032.wav
# Error encountered while parsing file:  UrbanSound\children_playing\174786.wav
# Error encountered while parsing file:  UrbanSound\children_playing\175296.wav
# Error encountered while parsing file:  UrbanSound\drilling\135849.wav
# Error encountered while parsing file:  UrbanSound\drilling\137815.wav
# Error encountered while parsing file:  UrbanSound\drilling\139000.wav
# Error encountered while parsing file:  UrbanSound\drilling\140824.wav
# Error encountered while parsing file:  UrbanSound\drilling\14110.wav
# Error encountered while parsing file:  UrbanSound\drilling\14111.wav
# Error encountered while parsing file:  UrbanSound\drilling\14113.wav
# Error encountered while parsing file:  UrbanSound\drilling\14114.wav
# Error encountered while parsing file:  UrbanSound\drilling\14115.wav
# Error encountered while parsing file:  UrbanSound\drilling\144351.wav
# Error encountered while parsing file:  UrbanSound\drilling\146244.wav
# Error encountered while parsing file:  UrbanSound\drilling\146249.wav
# Error encountered while parsing file:  UrbanSound\drilling\147019.wav
# Error encountered while parsing file:  UrbanSound\drilling\147764.wav
# Error encountered while parsing file:  UrbanSound\drilling\156362.wav
# Error encountered while parsing file:  UrbanSound\drilling\161129.wav
# Error encountered while parsing file:  UrbanSound\drilling\165640.wav
# Error encountered while parsing file:  UrbanSound\drilling\165641.wav
# Error encountered while parsing file:  UrbanSound\drilling\165642.wav
# Error encountered while parsing file:  UrbanSound\drilling\165643.wav
# Error encountered while parsing file:  UrbanSound\drilling\165644.wav
# Error encountered while parsing file:  UrbanSound\drilling\165645.wav
# Error encountered while parsing file:  UrbanSound\drilling\165785.wav
# Error encountered while parsing file:  UrbanSound\drilling\165786.wav
# Error encountered while parsing file:  UrbanSound\drilling\166931.wav
# Error encountered while parsing file:  UrbanSound\drilling\167701.wav
# Error encountered while parsing file:  UrbanSound\drilling\167702.wav
# Error encountered while parsing file:  UrbanSound\drilling\167750.wav
# Error encountered while parsing file:  UrbanSound\drilling\168037.wav
# Error encountered while parsing file:  UrbanSound\drilling\169466.wav
# Error encountered while parsing file:  UrbanSound\drilling\17913.wav
# Error encountered while parsing file:  UrbanSound\drilling\179212.wav
# Error encountered while parsing file:  UrbanSound\drilling\180029.wav
# Error encountered while parsing file:  UrbanSound\drilling\180937.wav
# Error encountered while parsing file:  UrbanSound\drilling\181624.wav
# Error encountered while parsing file:  UrbanSound\drilling\187863.wav
# Error encountered while parsing file:  UrbanSound\drilling\19007.wav
# Error encountered while parsing file:  UrbanSound\drilling\199929.wav
# Error encountered while parsing file:  UrbanSound\drilling\205610.wav
# Error encountered while parsing file:  UrbanSound\drilling\205874.wav
# Error encountered while parsing file:  UrbanSound\drilling\205878.wav
# Error encountered while parsing file:  UrbanSound\drilling\29721.wav
# Error encountered while parsing file:  UrbanSound\drilling\29722.wav
# Error encountered while parsing file:  UrbanSound\drilling\34621.wav
# Error encountered while parsing file:  UrbanSound\drilling\34643.wav
# Error encountered while parsing file:  UrbanSound\drilling\39532.wav
# Error encountered while parsing file:  UrbanSound\drilling\39533.wav
# Error encountered while parsing file:  UrbanSound\drilling\42324.wav
# Error encountered while parsing file:  UrbanSound\drilling\42937.wav
# Error encountered while parsing file:  UrbanSound\drilling\46668.wav
# Error encountered while parsing file:  UrbanSound\drilling\46669.wav
# Error encountered while parsing file:  UrbanSound\siren\54898.wav
# Error encountered while parsing file:  UrbanSound\siren\57323.wav
# Error encountered while parsing file:  UrbanSound\siren\62878.wav
# Error encountered while parsing file:  UrbanSound\siren\66601.wav
# Error encountered while parsing file:  UrbanSound\siren\66996.wav
# Error encountered while parsing file:  UrbanSound\siren\71177.wav
# Error encountered while parsing file:  UrbanSound\siren\74364.wav
# Error encountered while parsing file:  UrbanSound\siren\74726.wav
# Error encountered while parsing file:  UrbanSound\siren\88121.wav
# Error encountered while parsing file:  UrbanSound\siren\90014.wav
# Error encountered while parsing file:  UrbanSound\siren\90846.wav
# Error encountered while parsing file:  UrbanSound\siren\94636.wav
# Error encountered while parsing file:  UrbanSound\siren\96657.wav
# Error encountered while parsing file:  UrbanSound\siren\98525.wav
# Error encountered while parsing file:  UrbanSound\siren\98536.wav
# Error encountered while parsing file:  UrbanSound\street_music\101848.wav
# Error encountered while parsing file:  UrbanSound\street_music\108041.wav
# Error encountered while parsing file:  UrbanSound\street_music\108357.wav
# Error encountered while parsing file:  UrbanSound\street_music\109263.wav
# Error encountered while parsing file:  UrbanSound\street_music\113601.wav
# Error encountered while parsing file:  UrbanSound\street_music\115239.wav
# Error encountered while parsing file:  UrbanSound\street_music\115240.wav
# Error encountered while parsing file:  UrbanSound\street_music\115241.wav
# Error encountered while parsing file:  UrbanSound\street_music\115242.wav
# Error encountered while parsing file:  UrbanSound\street_music\115243.wav
# Error encountered while parsing file:  UrbanSound\street_music\115415.wav
# Error encountered while parsing file:  UrbanSound\street_music\115418.wav
# Error encountered while parsing file:  UrbanSound\street_music\117889.wav
# Error encountered while parsing file:  UrbanSound\street_music\122738.wav
# Error encountered while parsing file:  UrbanSound\street_music\124489.wav
# Error encountered while parsing file:  UrbanSound\street_music\128152.wav
# Error encountered while parsing file:  UrbanSound\street_music\132108.wav
# Error encountered while parsing file:  UrbanSound\street_music\132162.wav
# Error encountered while parsing file:  UrbanSound\street_music\136558.wav
# Error encountered while parsing file:  UrbanSound\street_music\137156.wav
# Error encountered while parsing file:  UrbanSound\street_music\14385.wav
# Error encountered while parsing file:  UrbanSound\street_music\14386.wav
# Error encountered while parsing file:  UrbanSound\street_music\14387.wav
# Error encountered while parsing file:  UrbanSound\street_music\14527.wav
# Error encountered while parsing file:  UrbanSound\street_music\147491.wav
# Error encountered while parsing file:  UrbanSound\street_music\149254.wav
# Error encountered while parsing file:  UrbanSound\street_music\149929.wav
# Error encountered while parsing file:  UrbanSound\street_music\152570.wav
# Error encountered while parsing file:  UrbanSound\street_music\155044.wav
# Error encountered while parsing file:  UrbanSound\street_music\155127.wav
# Error encountered while parsing file:  UrbanSound\street_music\155202.wav
# Error encountered while parsing file:  UrbanSound\street_music\155212.wav
# Error encountered while parsing file:  UrbanSound\street_music\155217.wav
# Error encountered while parsing file:  UrbanSound\street_music\155227.wav
# Error encountered while parsing file:  UrbanSound\street_music\155241.wav
# Error encountered while parsing file:  UrbanSound\street_music\155242.wav
# Error encountered while parsing file:  UrbanSound\street_music\155243.wav
# Error encountered while parsing file:  UrbanSound\street_music\157940.wav
# Error encountered while parsing file:  UrbanSound\street_music\161702.wav
# Error encountered while parsing file:  UrbanSound\street_music\164344.wav
# Error encountered while parsing file:  UrbanSound\street_music\164377.wav
# Error encountered while parsing file:  UrbanSound\street_music\165192.wav
# Error encountered while parsing file:  UrbanSound\street_music\168713.wav
# Error encountered while parsing file:  UrbanSound\street_music\168906.wav
# Error encountered while parsing file:  UrbanSound\street_music\171165.wav
# Error encountered while parsing file:  UrbanSound\street_music\171184.wav
# Error encountered while parsing file:  UrbanSound\street_music\171388.wav
# Error encountered while parsing file:  UrbanSound\street_music\171406.wav
# Error encountered while parsing file:  UrbanSound\street_music\171478.wav
# Error encountered while parsing file:  UrbanSound\street_music\172314.wav
# Error encountered while parsing file:  UrbanSound\street_music\172315.wav
# Error encountered while parsing file:  UrbanSound\street_music\172460.wav
# Error encountered while parsing file:  UrbanSound\street_music\172519.wav
# Error encountered while parsing file:  UrbanSound\street_music\173891.wav
# Error encountered while parsing file:  UrbanSound\street_music\180057.wav
# Error encountered while parsing file:  UrbanSound\street_music\182103.wav
# Error encountered while parsing file:  UrbanSound\street_music\185373.wav
# Error encountered while parsing file:  UrbanSound\street_music\185374.wav
# Error encountered while parsing file:  UrbanSound\street_music\185375.wav
# Error encountered while parsing file:  UrbanSound\street_music\186336.wav
# Error encountered while parsing file:  UrbanSound\street_music\186339.wav
# Error encountered while parsing file:  UrbanSound\street_music\189825.wav
# Error encountered while parsing file:  UrbanSound\street_music\196384.wav
# Error encountered while parsing file:  UrbanSound\street_music\202334.wav
# Error encountered while parsing file:  UrbanSound\street_music\203424.wav
# Error encountered while parsing file:  UrbanSound\street_music\203654.wav
# Error encountered while parsing file:  UrbanSound\street_music\21683.wav
# Error encountered while parsing file:  UrbanSound\street_music\21684.wav
# Error encountered while parsing file:  UrbanSound\street_music\26270.wav
# Error encountered while parsing file:  UrbanSound\street_music\31973.wav
# Error encountered while parsing file:  UrbanSound\street_music\34866.wav
# Error encountered while parsing file:  UrbanSound\street_music\36263.wav
# Error encountered while parsing file:  UrbanSound\street_music\36264.wav
# Error encountered while parsing file:  UrbanSound\street_music\41364.wav
# Error encountered while parsing file:  UrbanSound\street_music\42953.wav
# Error encountered while parsing file:  UrbanSound\street_music\42954.wav
# Error encountered while parsing file:  UrbanSound\street_music\42955.wav
# Error encountered while parsing file:  UrbanSound\street_music\49485.wav
# Error encountered while parsing file:  UrbanSound\street_music\55728.wav
# Error encountered while parsing file:  UrbanSound\street_music\66000.wav
# Error encountered while parsing file:  UrbanSound\street_music\66324.wav
# Error encountered while parsing file:  UrbanSound\street_music\66599.wav
# Error encountered while parsing file:  UrbanSound\street_music\71866.wav
# Error encountered while parsing file:  UrbanSound\street_music\73277.wav
# Error encountered while parsing file:  UrbanSound\street_music\74226.wav
# Error encountered while parsing file:  UrbanSound\street_music\74458.wav
# Error encountered while parsing file:  UrbanSound\street_music\76568.wav
# Error encountered while parsing file:  UrbanSound\street_music\79377.wav
# Error encountered while parsing file:  UrbanSound\street_music\89442.wav
# Error encountered while parsing file:  UrbanSound\street_music\89443.wav
# Error encountered while parsing file:  UrbanSound\street_music\94182.wav
# Error encountered while parsing file:  UrbanSound\street_music\94631.wav
# Error encountered while parsing file:  UrbanSound\street_music\96169.wav
# Error encountered while parsing file:  UrbanSound\street_music\96475.wav
# Error encountered while parsing file:  UrbanSound\street_music\96920.wav
# Error encountered while parsing file:  UrbanSound\street_music\96921.wav
# Error encountered while parsing file:  UrbanSound\street_music\98202.wav
# Error encountered while parsing file:  UrbanSound\street_music\98263.wav
# Error encountered while parsing file:  UrbanSound\street_music\99157.wav
# Error encountered while parsing file:  UrbanSound\street_music\99710.wav

# %% [markdown]
# ```We Store it in this DS cause it takes a fuck ton of time to load into librosa and like hell I'm doing that again```

# %% [markdown]
# ## Training The Model

# %%
#CONFIFURABLES
EPOCHS = 5 
BATCH_SIZE = 32
model.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE)

# %% [markdown]
# # Running the Model in Realtime

# %%
chunk_duration = 0.5 # Each read length in seconds from mic.
fs = 44100 # sampling rate for mic
chunk_samples = int(fs * chunk_duration) # Each read length in number of samples.

# Each model input data duration in seconds, need to be an integer numbers of chunk_duration
feed_duration = 10 # Seconds 
feed_samples = int(fs * feed_duration)

assert(feed_duration/chunk_duration == int(feed_duration/chunk_duration))

# %%
def get_audio_input_stream(callback):
    stream = pyaudio.PyAudio().open(
        format=pyaudio.paInt16,
        channels=1,
        rate=fs,
        input=True,
        frames_per_buffer=chunk_samples,
        input_device_index=0,
        stream_callback=callback)
    return stream

# %%
import pyaudio
from queue import Queue
from threading import Thread
import sys
import time


# Queue to communiate between the audio callback and main thread
q = Queue()

run = True

silence_threshold = 100

# Run the demo for a timeout seconds
timeout = time.time() + 0.5*60  # 0.5 minutes from now # Runtime 

# Data buffer for the input wavform
data = np.zeros(feed_samples, dtype='int16')

def callback(in_data, frame_count, time_info, status):
    global run, timeout, data, silence_threshold    
    if time.time() > timeout:
        run = False        
    data0 = np.frombuffer(in_data, dtype='int16')
    if np.abs(data0).mean() < silence_threshold:
        sys.stdout.write('-')
        return (in_data, pyaudio.paContinue)
    else:
        sys.stdout.write('.')
    data = np.append(data,data0)    
    if len(data) > feed_samples:
        data = data[-feed_samples:]
        # Process data async by sending a queue.
        q.put(data)
    return (in_data, pyaudio.paContinue)

stream = get_audio_input_stream(callback)
stream.start_stream()


try:
    while run:
        data = q.get()
        spectrum = get_spectrogram(data)
        preds = detect_triggerword_spectrum(spectrum)
        new_trigger = has_new_triggerword(preds, chunk_duration, feed_duration)
        if new_trigger:
            sys.stdout.write('1')
except (KeyboardInterrupt, SystemExit):
    stream.stop_stream()
    stream.close()
    timeout = time.time()
    run = False
        
stream.stop_stream()
stream.close()

# %% [markdown]
# * http://aqibsaeed.github.io/2016-09-03-urban-sound-classification-part-1/
# * https://medium.com/gradientcrescent/urban-sound-classification-using-convolutional-neural-networks-with-keras-theory-and-486e92785df4
# * Trigger Word
